# %%
import matplotlib.pyplot as plt
import numpy

# %%
data = numpy.loadtxt('/Users/chityantoe/Downloads/SWASHtestcases/a46jump/a46jmp02.tbl',skiprows=7) 
#https://stackoverflow.com/questions/20200353/reading-data-into-numpy-array-from-text-file
plt.plot(data[:,0] , -1*data[:,1])
plt.plot(data[:,0] , data[:,3])
plt.xlabel('Distance (m)')
plt.ylabel('Water depth (m)')
plt.xlim(0,30)
# Out:
# (0, 30)
